# %%
# =========================
# 5. EVALUATION & ETHICS
# =========================

import pandas as pd

# Load matches
df = pd.read_csv("matches.csv")

# Simple evaluation
threshold = 0.2
correct = 0

for s in df['Score']:
    if s > threshold:
        correct += 1

accuracy = correct / len(df)

print("Matching Accuracy:", accuracy)


# 🔥 Additional Analysis (Better Reporting)

avg_score = df['Score'].mean()
max_score = df['Score'].max()
min_score = df['Score'].min()

print("Average Score:", avg_score)
print("Max Score:", max_score)
print("Min Score:", min_score)
# Out:
# Matching Accuracy: 0.8075684380032206
# Average Score: 0.270464093194685
# Max Score: 0.6328785725986986
# Min Score: 0.0
